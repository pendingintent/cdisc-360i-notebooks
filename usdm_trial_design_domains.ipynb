# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Cellar/jupyterlab/4.4.4/libexec/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the libraries
import pandas as pd
import json

# %%
# read the USDM JSON for the LZT study
in_file = "data/usdm.json"
try:
    with open(in_file, 'r') as f:
        usdm = json.load(f)
except FileNotFoundError:
    print('The file {} was not found...'.format(in_file))

# %%
# Return the STUDYID
studyId = usdm['study']['versions'][0]['studyIdentifiers'][0]['text']

# %%
# Create the required study dictionary lists
elements = usdm['study']['versions'][0]['studyDesigns'][0]['elements']
cells = usdm['study']['versions'][0]['studyDesigns'][0]['studyCells']
arms = usdm['study']['versions'][0]['studyDesigns'][0]['arms']
epochs = usdm['study']['versions'][0]['studyDesigns'][0]['epochs']
encounters = usdm['study']['versions'][0]['studyDesigns'][0]['encounters']

# %%
# Create the elements dataframe
elementsDF = pd.DataFrame(elements, columns=['id','name','label','description','transitionStartRule','transitionEndRule'])
startRules = pd.json_normalize(elementsDF.transitionStartRule)
startRules.columns = [f'startRule_{col}' for col in startRules.columns]
endRules = pd.json_normalize(elementsDF.transitionEndRule)
endRules.columns = [f'endRule_{col}' for col in endRules.columns]
elementsDF = pd.concat([elementsDF,startRules,endRules], axis=1)
elementsDF = elementsDF.drop(columns=['transitionStartRule','transitionEndRule','startRule_id','startRule_name','startRule_extensionAttributes','startRule_label','startRule_description',
                             'startRule_instanceType','endRule_id','endRule_name','endRule_extensionAttributes','endRule_label','endRule_description','endRule_instanceType'])
elementsDF.rename(columns={'id':'elements.id', 'name':'elements.name', 'label':'elements.label', 'description':'elements.description', 'startRule_text':'elements.startRule_text',
                          'endRule_text':'elements.endRule_text'}, inplace=True)
elementsDF
# Out:
#       elements.id elements.name elements.label  \
# 0  StudyElement_1           EL1      Screening
# 1  StudyElement_2           EL2        Placebo
# 2  StudyElement_7           EL7      Follow up
# 3  StudyElement_3           EL3            Low
# 4  StudyElement_4           EL4   High - Start
# 5  StudyElement_5           EL5  High - Middle
# 6  StudyElement_6           EL6     High - End
#
#                                 elements.description  \
# 0                                  Screening Element
# 1                     Placebo TTS (adhesive patches)
# 2                                  Follow Up Element
# 3    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 4    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 5  Xanomeline TTS (adhesive patches) 50 cm2, 54 m...
# 6    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
#
#                              elements.startRule_text  \
# 0                                   Informed consent
# 1                       Administration of first dose
# 2  End of last scheduled visit on study (includin...
# 3                       Administration of first dose
# 4                                         Randomized
# 5  Administration of first dose (from patches sup...
# 6  Administration of first dose (from patches sup...
#
#                                elements.endRule_text
# 0  Completion of all screening activities and no ...
# 1                                                NaN
# 2  Completion of all specified followup activitie...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN

# %%
# Create the epochs dataframe
epochsDF = pd.DataFrame(epochs, columns=['id','name','label','description','type','previousId','nextId'])

types = pd.json_normalize(epochsDF.type)
types.columns = [f'type_{col}' for col in types.columns]
epochsDF = pd.concat([epochsDF,types], axis=1)
epochsDF = epochsDF.drop(columns=['type', 'type_id', 'type_extensionAttributes', 'type_codeSystem', 'type_codeSystemVersion', 'type_instanceType'])
epochsDF.rename(columns={'id':'epochs.id','name':'epochs.name','label':'epochs.label','description':'epochs.description','previousId':'epochs.previousId',
                        'nextId':'epochs.nextId','type_code':'epochs.type_code','type_decode':'epochs.type_decode'}, inplace=True)
epochsDF.insert(1, 'epochs.taetord', range(1, 1+len(epochsDF)))
epochsDF
# Out:
#       epochs.id  epochs.taetord  epochs.name     epochs.label  \
# 0  StudyEpoch_1               1    Screening        Screening
# 1  StudyEpoch_2               2  Treatment 1    Treatment One
# 2  StudyEpoch_3               3  Treatment 2    Treatment Two
# 3  StudyEpoch_4               4  Treatment 3  Treatment Three
# 4  StudyEpoch_5               5    Follow-Up        Follow Up
#
#   epochs.description epochs.previousId epochs.nextId epochs.type_code  \
# 0    Screening Epoch              None  StudyEpoch_2          C202487
# 1    Treatment Epoch      StudyEpoch_1  StudyEpoch_3          C101526
# 2    Treatment Epoch      StudyEpoch_2  StudyEpoch_4          C101526
# 3    Treatment Epoch      StudyEpoch_3  StudyEpoch_5          C101526
# 4    Follow-up Epoch      StudyEpoch_4          None          C202578
#
#   epochs.type_decode
# 0    Screening Epoch
# 1    Treatment Epoch
# 2    Treatment Epoch
# 3    Treatment Epoch
# 4    Follow-Up Epoch

# %%
# Create the arms dataframe
armsDF = pd.DataFrame(arms, columns=['id', 'name', 'label', 'description', 'type', 'dataOriginType'])
types = pd.json_normalize(armsDF.type)
types.columns = [f'type_{col}' for col in types.columns]
origins = pd.json_normalize(armsDF.dataOriginType)
origins.columns = [f'dataOriginType_{col}' for col in origins.columns]
armsDF = pd.concat([armsDF,types,origins], axis=1)
armsDF = armsDF.drop(columns=['type', 'type_id', 'type_extensionAttributes', 'type_codeSystem', 'type_codeSystemVersion', 'dataOriginType',
                             'type_instanceType', 'dataOriginType_id', 'dataOriginType_extensionAttributes', 'dataOriginType_codeSystem', 
                             'dataOriginType_codeSystemVersion', 'dataOriginType_instanceType'])
armsDF.rename(columns={'id':'arms.id','name':'arms.name','label':'arms.label','description':'arms.description','type_code':'arms.type_code',
                      'type_decode':'arms.type_decode','dataOriginType_code':'arms.dataOriginType_code', 'dataOriginType_decode':'arms.dataOriginType_decode'}, inplace=True)
armsDF
# Out:
#       arms.id             arms.name            arms.label  arms.description  \
# 0  StudyArm_1               Placebo               Placebo           Placebo
# 1  StudyArm_2   Xanomeline Low Dose   Xanomeline Low Dose  Active Substance
# 2  StudyArm_3  Xanomeline High Dose  Xanomeline High Dose  Active Substance
#
#   arms.type_code       arms.type_decode arms.dataOriginType_code  \
# 0        C174268    Placebo Control Arm                  C188866
# 1        C174267  Active Comparator Arm                  C188866
# 2        C174267  Active Comparator Arm                  C188866
#
#     arms.dataOriginType_decode
# 0  Data Generated Within Study
# 1  Data Generated Within Study
# 2  Data Generated Within Study

# %%
# Create the cells dataframe
cellsDF = pd.DataFrame(cells, columns = ['id','armId','epochId','elementIds'])
cellsDF['elementId'] = cellsDF['elementIds'].apply(lambda x: ''.join(map(str, x)))
cellsDF = cellsDF.drop(columns=['elementIds'])
cellsDF.rename(columns={'id':'cells.id','armId':'cells.armId','epochId':'cells.epochId','elementId':'cells.elementId'}, inplace=True)
cellsDF
# Out:
#         cells.id cells.armId cells.epochId cells.elementId
# 0    StudyCell_1  StudyArm_1  StudyEpoch_1  StudyElement_1
# 1    StudyCell_2  StudyArm_1  StudyEpoch_2  StudyElement_2
# 2    StudyCell_3  StudyArm_1  StudyEpoch_3  StudyElement_2
# 3    StudyCell_4  StudyArm_1  StudyEpoch_4  StudyElement_2
# 4    StudyCell_5  StudyArm_1  StudyEpoch_5  StudyElement_7
# 5    StudyCell_6  StudyArm_2  StudyEpoch_1  StudyElement_1
# 6    StudyCell_7  StudyArm_2  StudyEpoch_2  StudyElement_3
# 7    StudyCell_8  StudyArm_2  StudyEpoch_3  StudyElement_3
# 8    StudyCell_9  StudyArm_2  StudyEpoch_4  StudyElement_3
# 9   StudyCell_10  StudyArm_2  StudyEpoch_5  StudyElement_7
# 10  StudyCell_11  StudyArm_3  StudyEpoch_1  StudyElement_1
# 11  StudyCell_12  StudyArm_3  StudyEpoch_2  StudyElement_4
# 12  StudyCell_13  StudyArm_3  StudyEpoch_3  StudyElement_5
# 13  StudyCell_14  StudyArm_3  StudyEpoch_4  StudyElement_6
# 14  StudyCell_15  StudyArm_3  StudyEpoch_5  StudyElement_7

# %%
# Merge the cells and arms dataframes
ta_df = pd.merge(cellsDF, armsDF, how='left', left_on='cells.armId', right_on='arms.id')
ta_df = pd.merge(ta_df, epochsDF, how='left', left_on='cells.epochId', right_on='epochs.id')
ta_df = pd.merge(ta_df, elementsDF, how='left', left_on='cells.elementId', right_on='elements.id')
ta_df
# Out:
#         cells.id cells.armId cells.epochId cells.elementId     arms.id  \
# 0    StudyCell_1  StudyArm_1  StudyEpoch_1  StudyElement_1  StudyArm_1
# 1    StudyCell_2  StudyArm_1  StudyEpoch_2  StudyElement_2  StudyArm_1
# 2    StudyCell_3  StudyArm_1  StudyEpoch_3  StudyElement_2  StudyArm_1
# 3    StudyCell_4  StudyArm_1  StudyEpoch_4  StudyElement_2  StudyArm_1
# 4    StudyCell_5  StudyArm_1  StudyEpoch_5  StudyElement_7  StudyArm_1
# 5    StudyCell_6  StudyArm_2  StudyEpoch_1  StudyElement_1  StudyArm_2
# 6    StudyCell_7  StudyArm_2  StudyEpoch_2  StudyElement_3  StudyArm_2
# 7    StudyCell_8  StudyArm_2  StudyEpoch_3  StudyElement_3  StudyArm_2
# 8    StudyCell_9  StudyArm_2  StudyEpoch_4  StudyElement_3  StudyArm_2
# 9   StudyCell_10  StudyArm_2  StudyEpoch_5  StudyElement_7  StudyArm_2
# 10  StudyCell_11  StudyArm_3  StudyEpoch_1  StudyElement_1  StudyArm_3
# 11  StudyCell_12  StudyArm_3  StudyEpoch_2  StudyElement_4  StudyArm_3
# 12  StudyCell_13  StudyArm_3  StudyEpoch_3  StudyElement_5  StudyArm_3
# 13  StudyCell_14  StudyArm_3  StudyEpoch_4  StudyElement_6  StudyArm_3
# 14  StudyCell_15  StudyArm_3  StudyEpoch_5  StudyElement_7  StudyArm_3
#
#                arms.name            arms.label  arms.description  \
# 0                Placebo               Placebo           Placebo
# 1                Placebo               Placebo           Placebo
# 2                Placebo               Placebo           Placebo
# 3                Placebo               Placebo           Placebo
# 4                Placebo               Placebo           Placebo
# 5    Xanomeline Low Dose   Xanomeline Low Dose  Active Substance
# 6    Xanomeline Low Dose   Xanomeline Low Dose  Active Substance
# 7    Xanomeline Low Dose   Xanomeline Low Dose  Active Substance
# 8    Xanomeline Low Dose   Xanomeline Low Dose  Active Substance
# 9    Xanomeline Low Dose   Xanomeline Low Dose  Active Substance
# 10  Xanomeline High Dose  Xanomeline High Dose  Active Substance
# 11  Xanomeline High Dose  Xanomeline High Dose  Active Substance
# 12  Xanomeline High Dose  Xanomeline High Dose  Active Substance
# 13  Xanomeline High Dose  Xanomeline High Dose  Active Substance
# 14  Xanomeline High Dose  Xanomeline High Dose  Active Substance
#
#    arms.type_code       arms.type_decode  ... epochs.previousId epochs.nextId  \
# 0         C174268    Placebo Control Arm  ...              None  StudyEpoch_2
# 1         C174268    Placebo Control Arm  ...      StudyEpoch_1  StudyEpoch_3
# 2         C174268    Placebo Control Arm  ...      StudyEpoch_2  StudyEpoch_4
# 3         C174268    Placebo Control Arm  ...      StudyEpoch_3  StudyEpoch_5
# 4         C174268    Placebo Control Arm  ...      StudyEpoch_4          None
# 5         C174267  Active Comparator Arm  ...              None  StudyEpoch_2
# 6         C174267  Active Comparator Arm  ...      StudyEpoch_1  StudyEpoch_3
# 7         C174267  Active Comparator Arm  ...      StudyEpoch_2  StudyEpoch_4
# 8         C174267  Active Comparator Arm  ...      StudyEpoch_3  StudyEpoch_5
# 9         C174267  Active Comparator Arm  ...      StudyEpoch_4          None
# 10        C174267  Active Comparator Arm  ...              None  StudyEpoch_2
# 11        C174267  Active Comparator Arm  ...      StudyEpoch_1  StudyEpoch_3
# 12        C174267  Active Comparator Arm  ...      StudyEpoch_2  StudyEpoch_4
# 13        C174267  Active Comparator Arm  ...      StudyEpoch_3  StudyEpoch_5
# 14        C174267  Active Comparator Arm  ...      StudyEpoch_4          None
#
#    epochs.type_code  epochs.type_decode     elements.id elements.name  \
# 0           C202487     Screening Epoch  StudyElement_1           EL1
# 1           C101526     Treatment Epoch  StudyElement_2           EL2
# 2           C101526     Treatment Epoch  StudyElement_2           EL2
# 3           C101526     Treatment Epoch  StudyElement_2           EL2
# 4           C202578     Follow-Up Epoch  StudyElement_7           EL7
# 5           C202487     Screening Epoch  StudyElement_1           EL1
# 6           C101526     Treatment Epoch  StudyElement_3           EL3
# 7           C101526     Treatment Epoch  StudyElement_3           EL3
# 8           C101526     Treatment Epoch  StudyElement_3           EL3
# 9           C202578     Follow-Up Epoch  StudyElement_7           EL7
# 10          C202487     Screening Epoch  StudyElement_1           EL1
# 11          C101526     Treatment Epoch  StudyElement_4           EL4
# 12          C101526     Treatment Epoch  StudyElement_5           EL5
# 13          C101526     Treatment Epoch  StudyElement_6           EL6
# 14          C202578     Follow-Up Epoch  StudyElement_7           EL7
#
#    elements.label                               elements.description  \
# 0       Screening                                  Screening Element
# 1         Placebo                     Placebo TTS (adhesive patches)
# 2         Placebo                     Placebo TTS (adhesive patches)
# 3         Placebo                     Placebo TTS (adhesive patches)
# 4       Follow up                                  Follow Up Element
# 5       Screening                                  Screening Element
# 6             Low    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 7             Low    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 8             Low    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 9       Follow up                                  Follow Up Element
# 10      Screening                                  Screening Element
# 11   High - Start    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 12  High - Middle  Xanomeline TTS (adhesive patches) 50 cm2, 54 m...
# 13     High - End    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 14      Follow up                                  Follow Up Element
#
#                               elements.startRule_text  \
# 0                                    Informed consent
# 1                        Administration of first dose
# 2                        Administration of first dose
# 3                        Administration of first dose
# 4   End of last scheduled visit on study (includin...
# 5                                    Informed consent
# 6                        Administration of first dose
# 7                        Administration of first dose
# 8                        Administration of first dose
# 9   End of last scheduled visit on study (includin...
# 10                                   Informed consent
# 11                                         Randomized
# 12  Administration of first dose (from patches sup...
# 13  Administration of first dose (from patches sup...
# 14  End of last scheduled visit on study (includin...
#
#                                 elements.endRule_text
# 0   Completion of all screening activities and no ...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Completion of all specified followup activitie...
# 5   Completion of all screening activities and no ...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   Completion of all specified followup activitie...
# 10  Completion of all screening activities and no ...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  Completion of all specified followup activitie...
#
# [15 rows x 27 columns]

# %% [markdown]
# ## Create the final TA Trial Design Domain ##

# %% [markdown]
# ***TODO:** Need an example for calculating TATRANS, TABRANCH*

# %%
# Create the final TA trial design domain
ta = pd.DataFrame(ta_df, columns=['arms.name','arms.description','epochs.taetord','elements.name','elements.description','epochs.name'])
ta['STUDYID'] = studyId
ta['DOMAIN'] = 'TA'
ta['TABRANCH'] = None
ta['TATRANS'] = None
ta.rename(columns={'arms.name':'ARMCD','arms.description':'ARM','epochs.taetord':'TAETORD','elements.name':'ETCD','elements.description':'ELEMENT','epochs.name':'EPOCH'}, inplace=True)
ta = ta[['STUDYID','DOMAIN','ARMCD','ARM','TAETORD','ETCD','ELEMENT','TABRANCH','TATRANS','EPOCH']]
ta
# Out:
#         STUDYID DOMAIN                 ARMCD               ARM  TAETORD ETCD  \
# 0   H2Q-MC-LZZT     TA               Placebo           Placebo        1  EL1
# 1   H2Q-MC-LZZT     TA               Placebo           Placebo        2  EL2
# 2   H2Q-MC-LZZT     TA               Placebo           Placebo        3  EL2
# 3   H2Q-MC-LZZT     TA               Placebo           Placebo        4  EL2
# 4   H2Q-MC-LZZT     TA               Placebo           Placebo        5  EL7
# 5   H2Q-MC-LZZT     TA   Xanomeline Low Dose  Active Substance        1  EL1
# 6   H2Q-MC-LZZT     TA   Xanomeline Low Dose  Active Substance        2  EL3
# 7   H2Q-MC-LZZT     TA   Xanomeline Low Dose  Active Substance        3  EL3
# 8   H2Q-MC-LZZT     TA   Xanomeline Low Dose  Active Substance        4  EL3
# 9   H2Q-MC-LZZT     TA   Xanomeline Low Dose  Active Substance        5  EL7
# 10  H2Q-MC-LZZT     TA  Xanomeline High Dose  Active Substance        1  EL1
# 11  H2Q-MC-LZZT     TA  Xanomeline High Dose  Active Substance        2  EL4
# 12  H2Q-MC-LZZT     TA  Xanomeline High Dose  Active Substance        3  EL5
# 13  H2Q-MC-LZZT     TA  Xanomeline High Dose  Active Substance        4  EL6
# 14  H2Q-MC-LZZT     TA  Xanomeline High Dose  Active Substance        5  EL7
#
#                                               ELEMENT TABRANCH TATRANS  \
# 0                                   Screening Element     None    None
# 1                      Placebo TTS (adhesive patches)     None    None
# 2                      Placebo TTS (adhesive patches)     None    None
# 3                      Placebo TTS (adhesive patches)     None    None
# 4                                   Follow Up Element     None    None
# 5                                   Screening Element     None    None
# 6     Xanomeline TTS (adhesive patches) 50 cm2, 54 mg     None    None
# 7     Xanomeline TTS (adhesive patches) 50 cm2, 54 mg     None    None
# 8     Xanomeline TTS (adhesive patches) 50 cm2, 54 mg     None    None
# 9                                   Follow Up Element     None    None
# 10                                  Screening Element     None    None
# 11    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg     None    None
# 12  Xanomeline TTS (adhesive patches) 50 cm2, 54 m...     None    None
# 13    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg     None    None
# 14                                  Follow Up Element     None    None
#
#           EPOCH
# 0     Screening
# 1   Treatment 1
# 2   Treatment 2
# 3   Treatment 3
# 4     Follow-Up
# 5     Screening
# 6   Treatment 1
# 7   Treatment 2
# 8   Treatment 3
# 9     Follow-Up
# 10    Screening
# 11  Treatment 1
# 12  Treatment 2
# 13  Treatment 3
# 14    Follow-Up

# %% [markdown]
# ## Create the final TE Trial Design Domain

# %% [markdown]
# ***TODO:** Create logic to calculate TEDUR
# Select scheduleInstances that relate to start of the associated StudyEpoch associated with the corresponding
# study Element via StudyCell. Select the scheduleInstance associated with the start of the next studyEpoch. Use
# Timing.values of all related timings that specify the period inbetween for calculation of the total element duration.*

# %%
# Create the final TE Trial Design Domain
te = pd.DataFrame(ta_df,columns=['elements.name','elements.description','elements.startRule_text','elements.endRule_text'])
te['STUDYID'] = studyId
te['DOMAIN'] = 'TE'
te['TEDUR'] = None
te.rename(columns={'elements.name':'ETCD','elements.description':'ELEMENT','elements.startRule_text':'TESTRL','elements.endRule_text':'TEENRL'}, inplace=True)
te = te[['STUDYID','DOMAIN','ETCD','ELEMENT','TESTRL','TEENRL','TEDUR']]
te
# Out:
#         STUDYID DOMAIN ETCD  \
# 0   H2Q-MC-LZZT     TE  EL1
# 1   H2Q-MC-LZZT     TE  EL2
# 2   H2Q-MC-LZZT     TE  EL2
# 3   H2Q-MC-LZZT     TE  EL2
# 4   H2Q-MC-LZZT     TE  EL7
# 5   H2Q-MC-LZZT     TE  EL1
# 6   H2Q-MC-LZZT     TE  EL3
# 7   H2Q-MC-LZZT     TE  EL3
# 8   H2Q-MC-LZZT     TE  EL3
# 9   H2Q-MC-LZZT     TE  EL7
# 10  H2Q-MC-LZZT     TE  EL1
# 11  H2Q-MC-LZZT     TE  EL4
# 12  H2Q-MC-LZZT     TE  EL5
# 13  H2Q-MC-LZZT     TE  EL6
# 14  H2Q-MC-LZZT     TE  EL7
#
#                                               ELEMENT  \
# 0                                   Screening Element
# 1                      Placebo TTS (adhesive patches)
# 2                      Placebo TTS (adhesive patches)
# 3                      Placebo TTS (adhesive patches)
# 4                                   Follow Up Element
# 5                                   Screening Element
# 6     Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 7     Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 8     Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 9                                   Follow Up Element
# 10                                  Screening Element
# 11    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 12  Xanomeline TTS (adhesive patches) 50 cm2, 54 m...
# 13    Xanomeline TTS (adhesive patches) 50 cm2, 54 mg
# 14                                  Follow Up Element
#
#                                                TESTRL  \
# 0                                    Informed consent
# 1                        Administration of first dose
# 2                        Administration of first dose
# 3                        Administration of first dose
# 4   End of last scheduled visit on study (includin...
# 5                                    Informed consent
# 6                        Administration of first dose
# 7                        Administration of first dose
# 8                        Administration of first dose
# 9   End of last scheduled visit on study (includin...
# 10                                   Informed consent
# 11                                         Randomized
# 12  Administration of first dose (from patches sup...
# 13  Administration of first dose (from patches sup...
# 14  End of last scheduled visit on study (includin...
#
#                                                TEENRL TEDUR
# 0   Completion of all screening activities and no ...  None
# 1                                                 NaN  None
# 2                                                 NaN  None
# 3                                                 NaN  None
# 4   Completion of all specified followup activitie...  None
# 5   Completion of all screening activities and no ...  None
# 6                                                 NaN  None
# 7                                                 NaN  None
# 8                                                 NaN  None
# 9   Completion of all specified followup activitie...  None
# 10  Completion of all screening activities and no ...  None
# 11                                                NaN  None
# 12                                                NaN  None
# 13                                                NaN  None
# 14  Completion of all specified followup activitie...  None

# %% [markdown]
# ## Create the final TV Trial Design Domain ##

# %% [markdown]
# *Because the trial visits are the same for all arms, the ARMCD should be left blank*

# %%
# create the encounters dataframe
encountersDF = pd.DataFrame(encounters, columns=['id','name','label','description','type','previousId','nextId',
                                                 'scheduledAtId','transitionStartRule','transitionEndRule'])
types = pd.json_normalize(encountersDF.type)
types.columns = [f'type_{col}' for col in types.columns]
startRules = pd.json_normalize(encountersDF.transitionStartRule)
startRules.columns = [f'startRule_{col}' for col in startRules.columns]
endRules = pd.json_normalize(encountersDF.transitionEndRule)
endRules.columns = [f'endRule_{col}' for col in endRules.columns]
encountersDF = pd.concat([encountersDF,types,startRules,endRules], axis=1)
encountersDF = encountersDF.drop(columns=['type','transitionStartRule','transitionEndRule','startRule_description',
                                          'startRule_extensionAttributes','startRule_instanceType','type_extensionAttributes',
                                         'startRule_name','startRule_label','type_codeSystem','type_codeSystemVersion',
                                         'type_instanceType','endRule_extensionAttributes','endRule_name','endRule_label',
                                         'endRule_description','endRule_instanceType'])
encountersDF.rename(columns={'id':'encounter.id','name':'encounter.name','label':'encounter.label','description':'encounter.description',
                             'previousId':'encounter.previousId','nextId':'encounter.nextId','scheduledAtId':'encounter.scheduledAtId',
                             'type_id':'encounter.type_id','type_code':'encounter.type_code','type_decode':'encounter.type_decode',
                             'startRule_id':'encounter.startRule_id','startRule_text':'encounter.startRule_text','endRule_id':'encounter.endRule_id',
                             'endRule_text':'encounter.endRule_text'}, inplace=True)

#encountersDF.head()

# %% [markdown]
# *Create a timings dataframe for the retrieval of VISITDY variable*

# %%
timings = usdm['study']['versions'][0]['studyDesigns'][0]['scheduleTimelines'][0]['timings']
timingsDF = pd.DataFrame(timings, columns=['id','name','label','description','value'])
timingsDF.rename(columns={'id':'timing.id','name':'timing.name','label':'timing.label','description':'timing.description','value':'timing.value'}, inplace=True)
#timingsDF.head()

# %%
# Merge encounters and timings dataframes to include the VISITDY (timings.timing.value)
tv = pd.merge(encountersDF, timingsDF, how='left', left_on='encounter.scheduledAtId', right_on='timing.id')
tv = pd.DataFrame(tv, columns=['encounter.name','timing.value','encounter.startRule_text','encounter.endRule_text'])
tv['STUDYID'] = studyId
tv['DOMAIN'] = 'TV'
tv.insert(1, 'encounter.visitnum', range(1, 1+len(encountersDF)))
tv.rename(columns={'encounter.name':'VISIT','encounter.visitnum':'VISITNUM','timing.value':'VISITDY','encounter.startRule_text':'TVSTRL','encounter.endRule_text':'TVENRL'}, inplace=True)
tv = tv[['STUDYID','DOMAIN','VISITNUM','VISIT','VISITDY','TVSTRL','TVENRL']]
tv
# Out:
#         STUDYID DOMAIN  VISITNUM VISIT VISITDY  \
# 0   H2Q-MC-LZZT     TV         1    E1     NaN
# 1   H2Q-MC-LZZT     TV         2    E2     P2D
# 2   H2Q-MC-LZZT     TV         3    E3     NaN
# 3   H2Q-MC-LZZT     TV         4    E4     P2W
# 4   H2Q-MC-LZZT     TV         5    E5     P4W
# 5   H2Q-MC-LZZT     TV         6    E7     P6W
# 6   H2Q-MC-LZZT     TV         7    E8     P8W
# 7   H2Q-MC-LZZT     TV         8    E9    P12W
# 8   H2Q-MC-LZZT     TV         9   E10    P16W
# 9   H2Q-MC-LZZT     TV        10   E11    P20W
# 10  H2Q-MC-LZZT     TV        11   E12    P24W
# 11  H2Q-MC-LZZT     TV        12   E13    P26W
#
#                                                TVSTRL  \
# 0                                  Subject identifier
# 1                                                 NaN
# 2   subject has connection of ambulatory ECG machi...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
#
#                                                TVENRL
# 0                  completion of screening activities
# 1   subject leaves clinic after connection of ambu...
# 2                                           Radomized
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                   End of treatment

# %% [markdown]
# *NOTE: There are issues with the USDM for this study.  The values for the encounter start and end rule text should be completed for each encounter.*
#
# **encounter[i]['transitionStartRule']['text']**
#
# **encounter[i]['transitionEndRule']['text']**

# %% [markdown]
# ## Create the final TI Trial Design Domain

# %%
criteria = usdm['study']['versions'][0]['studyDesigns'][0]['eligibilityCriteria']
criteriaDF = pd.DataFrame(criteria, columns=['id','name','label','description','category','identifier'])
categories = pd.json_normalize(criteriaDF.category)
categories.columns = [f'category_{col}' for col in categories.columns]
criteriaDF = pd.concat([criteriaDF, categories], axis=1)
ti = pd.DataFrame(criteriaDF, columns=['name','label','category_decode'])
ti.rename(columns={'name':'IETESTCD','label':'IETEST','category_decode':'IECAT'}, inplace=True)
ti['STUDYID'] = studyId
ti['DOMAIN'] = 'TI'
ti = ti[['STUDYID','DOMAIN','IETESTCD','IETEST','IECAT']]
ti
# Out:
#         STUDYID DOMAIN IETESTCD  \
# 0   H2Q-MC-LZZT     TI     IN01
# 1   H2Q-MC-LZZT     TI     IN02
# 2   H2Q-MC-LZZT     TI     IN03
# 3   H2Q-MC-LZZT     TI     IN04
# 4   H2Q-MC-LZZT     TI     IN05
# 5   H2Q-MC-LZZT     TI     IN06
# 6   H2Q-MC-LZZT     TI     IN07
# 7   H2Q-MC-LZZT     TI     IN08
# 8   H2Q-MC-LZZT     TI     EX01
# 9   H2Q-MC-LZZT     TI     EX02
# 10  H2Q-MC-LZZT     TI     EX03
# 11  H2Q-MC-LZZT     TI     EX04
# 12  H2Q-MC-LZZT     TI     EX05
# 13  H2Q-MC-LZZT     TI     EX06
# 14  H2Q-MC-LZZT     TI     EX07
# 15  H2Q-MC-LZZT     TI     EX08
# 16  H2Q-MC-LZZT     TI     EX09
# 17  H2Q-MC-LZZT     TI     EX10
# 18  H2Q-MC-LZZT     TI     EX11
# 19  H2Q-MC-LZZT     TI     EX12
# 20  H2Q-MC-LZZT     TI     EX13
# 21  H2Q-MC-LZZT     TI     EX14
# 22  H2Q-MC-LZZT     TI     EX15
# 23  H2Q-MC-LZZT     TI     EX16
# 24  H2Q-MC-LZZT     TI     EX17
# 25  H2Q-MC-LZZT     TI     EX18
# 26  H2Q-MC-LZZT     TI     EX19
# 27  H2Q-MC-LZZT     TI     EX20
# 28  H2Q-MC-LZZT     TI     EX21
# 29  H2Q-MC-LZZT     TI     EX22
# 30  H2Q-MC-LZZT     TI     EX23
#
#                                                IETEST               IECAT
# 0                                 Age greater than 50  Inclusion Criteria
# 1                            Diagnosis of Alzheimer's  Inclusion Criteria
# 2                                          MMSE Score  Inclusion Criteria
# 3                            Hachinski Ischemic Score  Inclusion Criteria
# 4             CNS imaging comptaible with Alzheimer's  Inclusion Criteria
# 5                           Informed consent criteria  Inclusion Criteria
# 6                       Geographic proximity criteria  Inclusion Criteria
# 7                         Reliable caregiver criteria  Inclusion Criteria
# 8                             Previous study criteria  Exclusion Criteria
# 9                  Other Alzheimer's therapy criteria  Exclusion Criteria
# 10                           Serious illness criteria  Exclusion Criteria
# 11             Serious neurolocal conditions criteria  Exclusion Criteria
# 12                                Depression criteria  Exclusion Criteria
# 13  Schizophrenia, Bipolar, Ethanol or psychoactiv...  Exclusion Criteria
# 14                                   Syncope criteria  Exclusion Criteria
# 15                                       ECG Criteria  Exclusion Criteria
# 16                            Cardiovascular criteria  Exclusion Criteria
# 17                          Gastrointensinal criteria  Exclusion Criteria
# 18                                 Endocrine criteria  Exclusion Criteria
# 19                               Resporatory criteria  Exclusion Criteria
# 20                             Genitourinary criteria  Exclusion Criteria
# 21                             Rheumatologic criteria  Exclusion Criteria
# 22                                       HIV criteria  Exclusion Criteria
# 23    Neurosyphilis, Meningitis,Encephalitis criteria  Exclusion Criteria
# 24                         Malignant disease criteria  Exclusion Criteria
# 25           Ability to participate in study criteria  Exclusion Criteria
# 26                         Laboratory values criteria  Exclusion Criteria
# 27                 Central laboratory values criteria  Exclusion Criteria
# 28                                  Syphilia criteria  Exclusion Criteria
# 29                                Hemoglobin criteria  Exclusion Criteria
# 30                               Medications Criteria  Exclusion Criteria
